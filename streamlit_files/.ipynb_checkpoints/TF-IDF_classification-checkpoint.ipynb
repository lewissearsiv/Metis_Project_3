# %%
import streamlit as st
import pandas as pd
from word_finder import *
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')


############################################
#Fit the random Forest classifier for wines#
############################################

binary_features = pd.read_csv('Count_Vec.csv').iloc[:,1:]
target = pd.read_csv('target.csv').iloc[:,1:]
target["binary_country"] = target['country'].map({'US': 0, 'France': 1})
corpus = pd.read_csv('corpus.csv').iloc[:,1:]


#forest
forest=RandomForestClassifier(n_estimators=100)
forest.fit(binary_features,target['country'])
# Out:
# RandomForestClassifier()

# %%
forest_prediction('steel and mineral', forest)
# Out:
# 'France'

# %%
corpus_list = list(corpus.description)
corpus_list[:2]
# Out:
# ["First made in 2006, this succulent luscious Chardonnay is all about minerality. It's got a rich core of butterscotch and the seemingly endless layers of subtle flavors that biodynamic farming can bring. It spends 18 months on the lees prior to bottling. Drink now through 2028.",
#  "The apogee of this ambitious winery's white wine efforts, this bottling of just two barrels of Clone 5 shows focused marzipan, marcona almond and white peach notes on the nose. The palate sizzles with saltiness and a lemony acidity that cuts through its brown butter richness with finesse. The finish is luxurious and long."]

# %%
import re
def clean_text(
    string: str, 
    punctuations=r'''!()-[]{};:'"\,<>./?@#$%^&*_~''',
    #We need to remove some stop words and geographic give aways
    stop_words=['the', 'a', 'and', 'is', 'be', 'will', 'france','french','california','america',
               'american','californian','burgundy','country','wine','west','east','north','south',
               'champagne', 'languedoc-roussillon','southwest', 'loire', 'valley', 'beaujolais', 'alsace',
                'rhône', 'washington','york','oregon']) -> str:
    """
    A method to clean text 
    """
    # Cleaning the urls
    string = re.sub(r'https?://\S+|www\.\S+', '', string)

    # Cleaning the html elements
    string = re.sub(r'<.*?>', '', string)

    # Removing the punctuations
    for x in string.lower(): 
        if x in punctuations: 
            string = string.replace(x, "") 

    # Converting the text to lower
    string = string.lower()

    # Removing stop words
    string = ' '.join([word for word in string.split() if word not in stop_words])

    # Cleaning the whitespaces
    string = re.sub(r'\s+', ' ', string).strip()
    
    #Remove numbers
    string = ''.join([i for i in string if not i.isdigit()])

    return string

#Get the text data and the target
X, Y = [clean_text(doc) for doc in corpus_list], list(target['country'])

#Vectorize the text
from sklearn.feature_extraction.text import TfidfVectorizer as tfidf
vectorizer = tfidf()
vectorized_X = vectorizer.fit_transform(X)
df_vec = pd.DataFrame(vectorized_X.toarray(), columns=vectorizer.get_feature_names())
df_vec.shape
# Out:
# (11019, 8993)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_vec, Y, test_size=0.2, random_state=1)

# %%
#forest
tfidf_forest=RandomForestClassifier(n_estimators=200)
tfidf_forest.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
tfidf_forest.score(X_train,y_train), tfidf_forest.score(X_test,y_test)
# Out:
# (1.0, 0.9868421052631579)

# %% [markdown]
# It's not a good sign when your model is fitting the train data perfectly. So let's restrict the max depth of the  random forest to try to reduce the overfitting.

# %%
#forest
tfidf_forest=RandomForestClassifier(n_estimators=200, max_depth = 25)
tfidf_forest.fit(X_train,y_train)
tfidf_forest.score(X_train,y_train), tfidf_forest.score(X_test,y_test)
# Out:
# (0.966988088485536, 0.956442831215971)

# %%
#Let's check the confusion matrix
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix

fig, ax = plt.subplots(figsize=(8,8))
plot_confusion_matrix(tfidf_forest, X_test, y_test, ax=ax)
ax.tick_params(axis='both', which='major', labelsize=18)
plt.grid(b = None)
plt.title('Confusion Matrix', fontweight="bold", fontsize=17);
plt.savefig('RandomForestCM.jpeg');

# %%
476/(476+90)
# Out:
# 0.8409893992932862

# %% [markdown]
# The model is definitely favoring precision over recall but overall it's not TOO bad. When a model is making one perfect though that's always a red flag. Let's just see how logistic does on the TF-IDF Vectorizer.

# %%
from sklearn.linear_model import LogisticRegression
logistic = LogisticRegression(C=0.5)
logistic.fit(X_train, y_train)
logistic.score(X_train,y_train), logistic.score(X_test,y_test)
# Out:
# (0.9724333522404991, 0.9736842105263158)

# %%
fig, ax = plt.subplots(figsize=(7, 7))
plot_confusion_matrix(logistic, X_test, y_test, ax=ax)
plt.grid(b = None)
plt.title('Logistic Regression Confusion Matrix', fontweight="bold", fontsize=15);

# %%
534/(534+38), 534/(534+13)
# Out:
# (0.9335664335664335, 0.9762340036563071)

# %% [markdown]
# It turns out that not only is the accuracy on unseen test data better, but logistic regression is giving us a much better F-1, or balance between precision and recall.

# %%
import numpy as np
def our_prediction(description, tfidf_vectorizer,num_total_documents):
    '''Take a description of a wine and predict the country.'''
    
    #clean text and get value counts:
    cleaned_text = clean_text(description)
    word_counts = np.unique(cleaned_text.split(), return_counts=True)
    
    #Extract vocab:
    all_words = list(tfidf_vectorizer.keys())
    word_freq = list(tfidf_vectorizer.values())
    
    
    
    return logistic.predict_proba(test_series)

# %%
our_prediction("This wine is oaky and buttery.", vectorizer)
# Out:
# (array(['buttery', 'oaky', 'this'], dtype='<U7'), array([1, 1, 1]))

# %%
new_vectorizer = tfidf(vocabulary = vectorizer.vocabulary_)

# %%
test_sample = new_vectorizer.fit([clean_text("This wine is oaky and buttery.")])

# %%
test_sample
# Out:
# TfidfVectorizer(vocabulary={'buttery': 0, 'oaky': 1, 'this': 2})

# %%
vectorizer.vocabulary_
# Out:
# {'first': 2889,
#  'made': 4611,
#  'in': 3852,
#  'this': 7972,
#  'succulent': 7597,
#  'luscious': 4575,
#  'chardonnay': 1304,
#  'all': 184,
#  'about': 11,
#  'minerality': 4908,
#  'its': 4009,
#  'got': 3351,
#  'rich': 6529,
#  'core': 1745,
#  'of': 5352,
#  'butterscotch': 1054,
#  'seemingly': 6846,
#  'endless': 2485,
#  'layers': 4265,
#  'subtle': 7579,
#  'flavors': 2933,
#  'that': 7931,
#  'biodynamic': 701,
#  'farming': 2769,
#  'can': 1123,
#  'bring': 912,
#  'it': 4005,
#  'spends': 7285,
#  'months': 4996,
#  'on': 5396,
#  'lees': 4297,
#  'prior': 6102,
#  'to': 8051,
#  'bottling': 833,
#  'drink': 2298,
#  'now': 5259,
#  'through': 8000,
#  'apogee': 285,
#  'ambitious': 229,
#  'winerys': 8831,
#  'white': 8773,
#  'efforts': 2416,
#  'just': 4097,
#  'two': 8225,
#  'barrels': 566,
#  'clone': 1480,
#  'shows': 6985,
#  'focused': 2980,
#  'marzipan': 4707,
#  'marcona': 4676,
#  'almond': 206,
#  'peach': 5695,
#  'notes': 5242,
#  'nose': 5229,
# ...

# %%
descriptions = ["This wine is oaky and buttery.", "steel barrels.", 
                "Not a great vintage but notes of lavender.", "Exploding with minerality unoaked and citrus."]
for description in descriptions:
    print(our_prediction(description, vectorizer))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-9db46414a23b> in <module>
#       2                 "Not a great vintage but notes of lavender.", "Exploding with minerality unoaked and citrus."]
#       3 for description in descriptions:
# ----> 4     print(our_prediction(description, vectorizer))
#
# <ipython-input-114-cc5585537d2a> in our_prediction(description, tfidf_vectorizer)
#       9
#      10     #Convert to pandas df to predict
# ---> 11     test_series = pd.DataFrame(test_sample.toarray(), columns=tfidf_vectorizer.get_feature_names())
#      12
#      13     return logistic.predict_proba(test_series)
#
# AttributeError: 'TfidfVectorizer' object has no attribute 'toarray'

# %%
vectorizer.transform(["This wine is oaky and buttery."])

# %%
logistic.predict_proba(X_test[[t == 'France' for t in y_test]])
# Out:
# array([[0.97167832, 0.02832168],
#        [0.85265348, 0.14734652],
#        [0.97655601, 0.02344399],
#        ...,
#        [0.97528126, 0.02471874],
#        [0.83822065, 0.16177935],
#        [0.65908469, 0.34091531]])

# %%
test_sample = vectorizer.fit_transform([clean_text(corpus_list[2])])
test_series = pd.DataFrame(test_sample.toarray(), columns=vectorizer.get_feature_names())
print(logistic.predict_proba(test_series))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-dd870737e4c2> in <module>
#       1 test_sample = vectorizer.fit_transform([clean_text(corpus_list[2])])
#       2 test_series = pd.DataFrame(test_sample.toarray(), columns=vectorizer.get_feature_names())
# ----> 3 print(logistic.predict_proba(test_series))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py in predict_proba(self, X)
#    1466                                                 self.solver == 'liblinear')))
#    1467         if ovr:
# -> 1468             return super()._predict_proba_lr(X)
#    1469         else:
#    1470             decision = self.decision_function(X)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_base.py in _predict_proba_lr(self, X)
#     319         multiclass is handled by normalizing that over all classes.
# ...
